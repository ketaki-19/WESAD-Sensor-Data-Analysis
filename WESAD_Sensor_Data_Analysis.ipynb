# %% [markdown]
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/FDA/Project2
# Out:
# /content/drive/My Drive/FDA/Project2

# %% [markdown]
# Converting pkl files

# %%
import pandas as pd
import pickle
with open('S7.pkl', 'rb') as q:
 k7 = pickle.load(q, encoding='latin1')
with open('S8.pkl', 'rb') as q:
 k8 = pickle.load(q, encoding='latin1')
with open('S9.pkl', 'rb') as q:
 k9 = pickle.load(q, encoding='latin1')
with open('S10.pkl', 'rb') as q:
 k10 = pickle.load(q, encoding='latin1')
with open('S13.pkl', 'rb') as q:
 k13 = pickle.load(q, encoding='latin1')

# %% [markdown]
# SUBJECT 7

# %%
#subject 7
import pandas as pd



chest_signals = k7['signal']['chest']


chest_df = pd.DataFrame({
    's_ACC_X': chest_signals['ACC'][:, 0],
    's_ACC_Y': chest_signals['ACC'][:, 1],
    's_ACC_Z': chest_signals['ACC'][:, 2],
    's_ECG': chest_signals['ECG'].flatten(),
    's_EMG': chest_signals['EMG'].flatten(),
    's_EDA': chest_signals['EDA'].flatten(),
    's_Temp': chest_signals['Temp'].flatten(),
    's_Resp': chest_signals['Resp'].flatten()
})


min_length = min(len(chest_df), len(k7['label']))

chest_df = chest_df.iloc[:min_length]
chest_df['label'] = k7['label'][:min_length]
chest_df['subject'] = k7['subject']


print(chest_df.head())
print("Label distribution:\n", chest_df['label'].value_counts())
chest_df['label'] = chest_df['label'].astype(int)


f_df = chest_df[chest_df['label'].isin([1, 2, 3, 4])]

print("Filtered label distribution:\n", f_df['label'].value_counts())
# Out:
#    s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG      s_EDA     s_Temp  \
# 0   1.0696  -0.0140   1.4612 -0.019226 -0.048843  12.506866  33.993530
# 1   1.0654  -0.0102   1.4222 -0.016937 -0.007004  12.468719  33.932678
# 2   1.0654   0.0042   1.3202 -0.016159  0.071777  12.506866  33.970703
# 3   1.0666   0.0202   1.1464 -0.012405  0.088486  12.506485  34.008759
# 4   1.0602   0.0310   0.9192 -0.020325  0.090271  12.504959  33.887085
#
#      s_Resp  label subject
# 0  1.832581      0      S7
# 1  1.835632      0      S7
# 2  1.856995      0      S7
# 3  1.829529      0      S7
# 4  1.817322      0      S7
# Label distribution:
#  label
# 0    1472098
# 1     830200
# 4     553001
# 2     448000
# 3     260401
# 7      37101
# 5      35000
# 6      30799
# Name: count, dtype: int64
# Filtered label distribution:
#  label
# 1    830200
# 4    553001
# 2    448000
# 3    260401
# Name: count, dtype: int64

# %% [markdown]
# Subject 8

# %%
# subject 8
import pandas as pd



chest_signals = k8['signal']['chest']


chest_df_s8 = pd.DataFrame({
    's_ACC_X': chest_signals['ACC'][:, 0],
    's_ACC_Y': chest_signals['ACC'][:, 1],
    's_ACC_Z': chest_signals['ACC'][:, 2],
    's_ECG': chest_signals['ECG'].flatten(),
    's_EMG': chest_signals['EMG'].flatten(),
    's_EDA': chest_signals['EDA'].flatten(),
    's_Temp': chest_signals['Temp'].flatten(),
    's_Resp': chest_signals['Resp'].flatten()
})


min_length = min(len(chest_df_s8), len(k8['label']))

chest_df_s8 = chest_df_s8.iloc[:min_length]
chest_df_s8['label'] = k8['label'][:min_length]
chest_df_s8['subject'] = k8['subject']


print(chest_df_s8.head())
print("Label distribution:\n", chest_df_s8['label'].value_counts())
chest_df_s8['label'] = chest_df_s8['label'].astype(int)

# Filter only required states (1, 2, 3, 4)
f_df8 = chest_df_s8[chest_df_s8['label'].isin([1, 2, 3, 4])]


print("Filtered label distribution:\n", f_df8['label'].value_counts())
# Out:
#    s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG     s_EDA     s_Temp  \
# 0   0.8746  -0.0232   0.2762  0.169510 -0.005356  4.368591  34.264893
# 1   0.8802  -0.0114   0.2638  0.166397  0.009933  4.372025  34.280182
# 2   0.8870   0.0002   0.2382  0.163376  0.014786  4.381943  34.263397
# 3   0.8954   0.0176   0.2030  0.153259  0.015884  4.365921  34.271027
# 4   0.9002   0.0326   0.1486  0.147629  0.028381  4.366684  34.261841
#
#      s_Resp  label subject
# 0 -1.718140      0      S8
# 1 -1.716614      0      S8
# 2 -1.705933      0      S8
# 3 -1.710510      0      S8
# 4 -1.713562      0      S8
# Label distribution:
#  label
# 0    1616300
# 1     818300
# 4     557200
# 2     469000
# 3     258999
# 7      36400
# 6      35701
# 5      34300
# Name: count, dtype: int64
# Filtered label distribution:
#  label
# 1    818300
# 4    557200
# 2    469000
# 3    258999
# Name: count, dtype: int64

# %% [markdown]
# Subject 9

# %%
#subject 9
import pandas as pd



chest_signals = k9['signal']['chest']


chest_df_s9 = pd.DataFrame({
    's_ACC_X': chest_signals['ACC'][:, 0],
    's_ACC_Y': chest_signals['ACC'][:, 1],
    's_ACC_Z': chest_signals['ACC'][:, 2],
    's_ECG': chest_signals['ECG'].flatten(),
    's_EMG': chest_signals['EMG'].flatten(),
    's_EDA': chest_signals['EDA'].flatten(),
    's_Temp': chest_signals['Temp'].flatten(),
    's_Resp': chest_signals['Resp'].flatten()
})


min_length = min(len(chest_df_s9), len(k9['label']))

chest_df_s9 = chest_df_s9.iloc[:min_length]
chest_df_s9['label'] = k9['label'][:min_length]
chest_df_s9['subject'] = k9['subject']


print(chest_df_s9.head())
print("Label distribution:\n", chest_df_s9['label'].value_counts())
chest_df_s9['label'] = chest_df_s9['label'].astype(int)

# Filter only required states (1, 2, 3, 4)
f_df9 = chest_df_s9[chest_df_s9['label'].isin([1, 2, 3, 4])]

print("Filtered label distribution:\n", f_df9['label'].value_counts())
# Out:
#    s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG     s_EDA     s_Temp  \
# 0   1.0786  -0.1046   0.5770 -0.050583  0.000916  1.961136  33.682251
# 1   1.1242  -0.0958   0.5558 -0.056808 -0.033371  1.978683  33.704956
# 2   1.1510  -0.0978   0.4706 -0.047653 -0.065369  1.960754  33.700439
# 3   1.1602  -0.1112   0.3726 -0.039047 -0.059738  1.955032  33.689789
# 4   1.1518  -0.1314   0.2450 -0.040329  0.003067  1.965714  33.656464
#
#      s_Resp  label subject
# 0 -0.985718      0      S9
# 1 -0.997925      0      S9
# 2 -0.970459      0      S9
# 3 -0.970459      0      S9
# 4 -0.984192      0      S9
# Label distribution:
#  label
# 0    1435700
# 1     826000
# 4     555100
# 2     451500
# 3     260400
# 6      43400
# 5      42000
# 7      42000
# Name: count, dtype: int64
# Filtered label distribution:
#  label
# 1    826000
# 4    555100
# 2    451500
# 3    260400
# Name: count, dtype: int64

# %% [markdown]
# Subject 10

# %%
#subject 10
import pandas as pd



chest_signals = k10['signal']['chest']


chest_df_s10 = pd.DataFrame({
    's_ACC_X': chest_signals['ACC'][:, 0],
    's_ACC_Y': chest_signals['ACC'][:, 1],
    's_ACC_Z': chest_signals['ACC'][:, 2],
    's_ECG': chest_signals['ECG'].flatten(),
    's_EMG': chest_signals['EMG'].flatten(),
    's_EDA': chest_signals['EDA'].flatten(),
    's_Temp': chest_signals['Temp'].flatten(),
    's_Resp': chest_signals['Resp'].flatten()
})


min_length = min(len(chest_df_s10), len(k10['label']))

chest_df_s10 = chest_df_s10.iloc[:min_length]
chest_df_s10['label'] = k10['label'][:min_length]
chest_df_s10['subject'] = k10['subject']


print(chest_df_s10.head())
print("Label distribution:\n", chest_df_s10['label'].value_counts())
chest_df_s10['label'] = chest_df_s10['label'].astype(int)

# Filter only required states (1, 2, 3, 4)
f_df10 = chest_df_s10[chest_df_s10['label'].isin([1, 2, 3, 4])]

print("Filtered label distribution:\n", f_df10['label'].value_counts())
# Out:
#    s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG     s_EDA     s_Temp  \
# 0   1.1278   0.1520   0.3416 -1.333694 -0.013687  0.716019  33.695862
# 1   1.0932   0.1888   0.2922 -1.327744 -0.021927  0.714493  33.741333
# 2   1.0354   0.2094   0.1858 -1.322067 -0.009018  0.715637  33.717072
# 3   0.9666   0.2118   0.0412 -1.316345 -0.002380  0.714874  33.741333
# 4   0.8916   0.2040  -0.1228 -1.310257  0.001053  0.715256  33.747406
#
#      s_Resp  label subject
# 0  0.213623      0     S10
# 1  0.192261      0     S10
# 2  0.205994      0     S10
# 3  0.193787      0     S10
# 4  0.172424      0     S10
# Label distribution:
#  label
# 0    1589000
# 1     826000
# 4     557200
# 2     507500
# 3     260400
# 7      39900
# 5      35700
# 6      31500
# Name: count, dtype: int64
# Filtered label distribution:
#  label
# 1    826000
# 4    557200
# 2    507500
# 3    260400
# Name: count, dtype: int64

# %% [markdown]
# Subject13

# %%
#subject13
import pandas as pd

chest_signals = k13['signal']['chest']

chest_df_s13 = pd.DataFrame({
    's_ACC_X': chest_signals['ACC'][:, 0],
    's_ACC_Y': chest_signals['ACC'][:, 1],
    's_ACC_Z': chest_signals['ACC'][:, 2],
    's_ECG': chest_signals['ECG'].flatten(),
    's_EMG': chest_signals['EMG'].flatten(),
    's_EDA': chest_signals['EDA'].flatten(),
    's_Temp': chest_signals['Temp'].flatten(),
    's_Resp': chest_signals['Resp'].flatten()
})

min_length = min(len(chest_df_s13), len(k13['label']))

chest_df_s13 = chest_df_s13.iloc[:min_length]
chest_df_s13['label'] = k13['label'][:min_length]
chest_df_s13['subject'] = k13['subject']


print(chest_df_s13.head())
print("Label distribution:\n", chest_df_s13['label'].value_counts())
chest_df_s13['label'] = chest_df_s13['label'].astype(int)


f_df13 = chest_df_s13[chest_df_s13['label'].isin([1, 2, 3, 4])]

print("Filtered label distribution:\n", f_df13['label'].value_counts())
# Out:
#    s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG     s_EDA     s_Temp  \
# 0   0.9726  -0.1412   0.2318 -0.272781 -0.004990  2.347183  32.627258
# 1   0.9910  -0.0828   0.2078 -0.271042 -0.047882  2.367783  32.622772
# 2   0.9978  -0.0230   0.0238 -0.263947 -0.067520  2.358627  32.621246
# 3   1.0114   0.0406  -0.2766 -0.255386 -0.041428  2.349091  32.603302
# 4   1.0318   0.0842  -0.4152 -0.261520  0.006638  2.359009  32.624237
#
#      s_Resp  label subject
# 0  0.050354      0     S13
# 1  0.404358      0     S13
# 2  0.405884      0     S13
# 3  0.404358      0     S13
# 4  0.396729      0     S13
# Label distribution:
#  label
# 0    1679300
# 1     826001
# 4     556499
# 2     464800
# 3     267400
# 5      34300
# 6      33600
# 7      14000
# Name: count, dtype: int64
# Filtered label distribution:
#  label
# 1    826001
# 4    556499
# 2    464800
# 3    267400
# Name: count, dtype: int64

# %%
#Combining the filtered data of every subject to one data frame
df_combined = pd.concat([f_df, f_df8, f_df9, f_df10,f_df13], ignore_index=True)
print(df_combined)
# Out:
#           s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG      s_EDA     s_Temp  \
# 0          0.9002  -0.0758  -0.2070 -0.013504 -0.031540  12.968826  34.202301
# 1          0.9018  -0.0744  -0.2090 -0.014694 -0.018723  12.967300  34.216064
# 2          0.8996  -0.0734  -0.2078 -0.014603 -0.012955  12.965775  34.217560
# 3          0.9014  -0.0750  -0.2088 -0.012955  0.005630  12.970352  34.222168
# 4          0.8964  -0.0726  -0.2074 -0.005539  0.014923  12.968826  34.197754
# ...           ...      ...      ...       ...       ...        ...        ...
# 10553896   0.8244  -0.0766  -0.4402  0.019638 -0.002884   3.594971  34.249634
# 10553897   0.8240  -0.0744  -0.4366  0.023849 -0.017441   3.611374  34.280182
# 10553898   0.8226  -0.0748  -0.4358  0.033737 -0.002701   3.586578  34.280182
# 10553899   0.8238  -0.0764  -0.4370  0.046829 -0.009933   3.599167  34.274109
# 10553900   0.8236  -0.0750  -0.4356  0.058868 -0.004166   3.598404  34.261841
#
# ...

# %%
# Sampling data for every subject
mental_states = {1: 'baseline', 2: 'stress', 3: 'amusement', 4: 'meditation'}

sampled_data = {state: [] for state in mental_states.values()}

sample_size = 4096
num_samples = 10

for subject in df_combined['subject'].unique():
    subject_data = df_combined[df_combined['subject'] == subject]
    for state_num, state_name in mental_states.items():
        state_data = subject_data[subject_data['label'] == state_num]
        print(f"Subject: {subject}, State: {state_name}, Rows Available: {len(state_data)}")


        total_required = sample_size * num_samples

        # 10 sequential, non-overlapping chunks
        for i in range(num_samples):
            start_idx = i * sample_size
            end_idx = start_idx + sample_size
            sampled_data[state_name].append(state_data.iloc[start_idx:end_idx])
# Out:
# Subject: S7, State: baseline, Rows Available: 830200
# Subject: S7, State: stress, Rows Available: 448000
# Subject: S7, State: amusement, Rows Available: 260401
# Subject: S7, State: meditation, Rows Available: 553001
# Subject: S8, State: baseline, Rows Available: 818300
# Subject: S8, State: stress, Rows Available: 469000
# Subject: S8, State: amusement, Rows Available: 258999
# Subject: S8, State: meditation, Rows Available: 557200
# Subject: S9, State: baseline, Rows Available: 826000
# Subject: S9, State: stress, Rows Available: 451500
# Subject: S9, State: amusement, Rows Available: 260400
# Subject: S9, State: meditation, Rows Available: 555100
# Subject: S10, State: baseline, Rows Available: 826000
# Subject: S10, State: stress, Rows Available: 507500
# Subject: S10, State: amusement, Rows Available: 260400
# Subject: S10, State: meditation, Rows Available: 557200
# Subject: S13, State: baseline, Rows Available: 826001
# Subject: S13, State: stress, Rows Available: 464800
# ...

# %%
sampled_data
# Out:
# {'baseline': [      s_ACC_X  s_ACC_Y  s_ACC_Z     s_ECG     s_EMG      s_EDA     s_Temp  \
#   0      0.9002  -0.0758  -0.2070 -0.013504 -0.031540  12.968826  34.202301
#   1      0.9018  -0.0744  -0.2090 -0.014694 -0.018723  12.967300  34.216064
#   2      0.8996  -0.0734  -0.2078 -0.014603 -0.012955  12.965775  34.217560
#   3      0.9014  -0.0750  -0.2088 -0.012955  0.005630  12.970352  34.222168
#   4      0.8964  -0.0726  -0.2074 -0.005539  0.014923  12.968826  34.197754
#   ...       ...      ...      ...       ...       ...        ...        ...
#   4091   0.9022  -0.0530  -0.1186 -0.070084 -0.017029  12.953186  34.219116
#   4092   0.9034  -0.0522  -0.1174 -0.063492 -0.008331  12.955093  34.229797
#   4093   0.9014  -0.0514  -0.1186 -0.061203 -0.004166  12.955093  34.219116
#   4094   0.9004  -0.0502  -0.1206 -0.059921  0.005356  12.952805  34.229797
#   4095   0.9014  -0.0510  -0.1222 -0.054794 -0.005539  12.954330  34.225220
#
#           s_Resp  label subject
# ...

# %%
# Function for calculateing entropy and complexity
import numpy as np


def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts)

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*(m-1)):, :]
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:])


def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

def weighted_ordinal_patterns(ts, embdim, embdelay):
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts)

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*(m-1)):, :]
    xm = np.mean(partition, axis=1)
    weight = np.mean((partition - xm[:, None])**2, axis=1)
    permutation = np.argsort(partition)
    idx = _hash(permutation)
    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = sum(weight[i == idx])

    return list(counts[counts != 0])

# %%
#calculating entropy for every sample in each subject
import matplotlib.pyplot as plt
import seaborn as sns
states = ['baseline', 'stress', 'amusement', 'meditation']
signals = ['s_ACC_X', 's_ACC_Y', 's_ACC_Z', 's_ECG', 's_EMG', 's_Temp', 's_Resp', 's_EDA']
all_data = []

for subject in df_combined['subject'].unique():
    subject_data = df_combined[df_combined['subject'] == subject]
    for state in states:
        state_data = subject_data[subject_data['label'] == list(mental_states.keys())[list(mental_states.values()).index(state)]]

        if len(state_data) > 0:

            for sample in sampled_data[state]:
              if sample['subject'].iloc[0] == subject:
                row_data = {'Subject': subject, 'State': state}
                for signal in signals:
                    ecg_signal = sample[signal][0:4095]
                    patterns = ordinal_patterns(ecg_signal, 4, 1)  #  ordinal patterns for d=4 and t=1
                    row_data[f'{signal}_Entropy'] = p_entropy(patterns)
                    row_data[f'{signal}_Complexity'] = complexity(patterns)
                all_data.append(row_data)

df2 = pd.DataFrame(all_data)
# Out:
# <ipython-input-13-e87f777f24f9>:41: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:])
# <ipython-input-13-e87f777f24f9>:32: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   counts = np.zeros(np.math.factorial(m))

# %% [markdown]
# Plot for every subject and for every signal

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math


subjects = df2['Subject'].unique()
num_subjects = len(subjects)
num_signals = len(signals)


cols = 4
rows = math.ceil((num_subjects * num_signals) / cols)

fig, axes = plt.subplots(rows, cols, figsize=(20, 5 * rows))


axes = axes.flatten()

plot_idx = 0
for subject in subjects:
    for attr in signals:
        subject_df = df2[df2['Subject'] == subject]

        sns.scatterplot(
            ax=axes[plot_idx],
            data=subject_df,
            x=f"{attr}_Entropy",
            y=f"{attr}_Complexity",
            hue="State",
            palette="plasma",
            s=100,
        )

        axes[plot_idx].set_title(f"Subject {subject}, {attr}: PE vs Complexity")
        axes[plot_idx].set_xlabel("Permutation Entropy (PE)")
        axes[plot_idx].set_ylabel("Complexity")
        axes[plot_idx].legend(title="State", loc="best")
        axes[plot_idx].grid(True)

        plot_idx += 1


for i in range(plot_idx, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ```markdown
# # FDA Project 2: Mental State Analysis from Physiological Signals
#
# ## Project Overview
# This project aims to analyze various mental states (baseline, stress, amusement, meditation) using physiological signals collected from multiple subjects. The data is processed to extract meaningful features like Permutation Entropy (PE) and Complexity, which are then visualized to understand the differences across mental states.
#
# ## Data Sources
# The project utilizes `.pkl` files containing physiological data (chest signals) and corresponding labels for different subjects (S7, S8, S9, S10, S13).
#
# ## Data Processing Steps
# 1.  **Loading Data:** Physiological data (ACC, ECG, EMG, EDA, Temp, Resp) and labels are loaded from `.pkl` files for each subject.
# 2.  **DataFrame Creation:** Raw signal data is converted into pandas DataFrames, including a 'label' column (representing the mental state) and a 'subject' column.
# 3.  **Filtering:** Only data corresponding to specific mental states (1: baseline, 2: stress, 3: amusement, 4: meditation) is retained.
# 4.  **Combining Data:** Filtered data from all subjects is concatenated into a single DataFrame (`df_combined`).
# 5.  **Sampling:** For each subject and each mental state, 10 non-overlapping samples, each of 4096 data points, are extracted. This ensures uniform segments for feature extraction.
#
# ## Feature Engineering: Permutation Entropy and Complexity
# The project calculates two key features for each sampled signal:
# *   **Permutation Entropy (PE):** A measure of the complexity and predictability of a time series, indicating the order or disorder of the signal.
# *   **Complexity:** A measure related to the structural complexity of the time series, often used in conjunction with entropy.
#
# These features are computed for the following chest signals:
# *   `s_ACC_X`, `s_ACC_Y`, `s_ACC_Z` (Accelerometer data in X, Y, Z directions)
# *   `s_ECG` (Electrocardiogram)
# *   `s_EMG` (Electromyography)
# *   `s_Temp` (Temperature)
# *   `s_Resp` (Respiration)
# *   `s_EDA` (Electrodermal Activity)
#
# ## Analysis and Visualization
# After feature extraction, the calculated Permutation Entropy and Complexity values are plotted against each other for each signal and subject. These scatter plots help visualize how the mental states cluster in the PE-Complexity space, potentially revealing distinct patterns for different emotional and cognitive conditions.
#
# ## Libraries Used
# *   `pandas`: For data manipulation and analysis.
# *   `numpy`: For numerical operations.
# *   `matplotlib.pyplot`: For creating static, interactive, and animated visualizations.
# *   `seaborn`: For drawing attractive and informative statistical graphics.
#
# ## How to Run
# 1.  Ensure all required `.pkl` data files (S7.pkl, S8.pkl, S9.pkl, S10.pkl, S13.pkl) are present in the designated `/content/drive/My Drive/FDA/Project2` directory.
# 2.  Run the Jupyter/Colab notebook cells sequentially to load data, process it, extract features, and generate visualizations.
# ```
